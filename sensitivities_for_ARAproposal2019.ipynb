# %%
from limits import LimitFigure, ara_energies, ara_available, ara_projected_2026, ara_projected_2030, ara_projected_2025
import importlib
import limits
importlib.reload(limits)
import numpy as np

# %%
figure = LimitFigure(e_power=1, xlims=(1e6, 1e11), ylims=(2e-19, 2e-14), font_size=16, tick_size=14)
# figure.build_base_plot('ara',models = ['ahlers_1','ahlers_100','batista','batista_low_z','van_vliet2019', 'van_vliet2019_Elow', 'wittkowski_off','wittkowski','van_vliet2019_hard','van_vliet2019_soft','diagonal','kotera_FRII','vanvliet19_highE_hard','kotera'])
figure.build_base_plot('ara',models = ['ahlers_1','diagonal','van_vliet2019',"murase_grb","fang_pulsar_max"])
# figure.add_limit('ARA', ara_energies, ara_available*0.9,
#                 stations=2.44, years=1, color='black', linestyle="dotted",
#                 label='Available Data (2012-2019)')
figure.add_limit('ARA', ara_energies, ara_available*0.9,
                stations=2.44, years=1, color='black', linestyle="dotted",
                label='Available Data (2022)')
# figure.add_limit('ARA', ara_energies, ara_projected*0.9,
#                 stations=2.44, years=1, color='black', linestyle='dashed',
#                 label='Projected Data (2012-2022)')
figure.add_limit('ARA', ara_energies, ara_projected_2026*0.9,
                stations=2.44, years=1, color='black', linestyle='dashed',
                label='ARA Trigger-level 2026', linewidth=1.5)
figure.add_limit('ARA', ara_energies, ara_projected_2030*0.9,
                stations=2.44, years=1, color='black', linestyle='dashed',
                label='ARA Trigger-level 2030')
figure.ax.annotate('SES', xy=(1.5e8,1.2e-17), rotation=-48, fontsize=14)

figure.show(legend_size=12, save_name='e1_sensitivity_plot_ara2022.pdf')
# Out:
# /users/PAS0654/jflaherty13/araAnalysis/araGrant/yearlyNeutrinosPlotting/limits.py:751: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2b7c3f33e0f0> has a label of '_child1' which cannot be automatically added to the legend.
#   self.ax.add_artist(plt.legend(handles=joined, loc=3,fontsize=legend_size))

# %%
##For Ilya's Analysis proposal which goes to 2025
figure = LimitFigure(e_power=1, xlims=(1e6, 1e11), ylims=(2e-19, 2e-14), font_size=16, tick_size=14)
# figure.build_base_plot('ara',models = ['ahlers_1','ahlers_100','batista','batista_low_z','van_vliet2019', 'van_vliet2019_Elow', 'wittkowski_off','wittkowski','van_vliet2019_hard','van_vliet2019_soft','diagonal','kotera_FRII','vanvliet19_highE_hard','kotera'])
figure.build_base_plot('ara',models = ['ahlers_1','diagonal','van_vliet2019',"murase_grb","fang_pulsar_max"])
# figure.add_limit('ARA', ara_energies, ara_available*0.9,
#                 stations=2.44, years=1, color='black', linestyle="dotted",
#                 label='Available Data (2012-2019)')
figure.add_limit('ARA', ara_energies, ara_available*0.9,
                stations=2.44, years=1, color='black', linestyle="dotted",
                label='ARA Available Data (2022)')
# figure.add_limit('ARA', ara_energies, ara_projected*0.9,
#                 stations=2.44, years=1, color='black', linestyle='dashed',
#                 label='Projected Data (2012-2022)')
figure.add_limit('ARA', ara_energies, ara_projected_2025*0.9,
                stations=2.44, years=1, color='black', linestyle='dashed',
                label='ARA Trigger-level 2025', linewidth=1.5)
# figure.add_limit('ARA', ara_energies, ara_projected_2030*0.9,
#                 stations=2.44, years=1, color='black', linestyle='dashed',
#                 label='ARA Trigger-level 2030')
figure.ax.annotate('SES', xy=(1.5e8,1.2e-17), rotation=-48, fontsize=14)

figure.show(legend_size=12, save_name='e1_sensitivity_plot_ara2022.pdf')
# Out:
# /users/PAS0654/jflaherty13/araAnalysis/araGrant/yearlyNeutrinosPlotting/limits.py:751: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2b7c42180f50> has a label of '_child1' which cannot be automatically added to the legend.
#   self.ax.add_artist(plt.legend(handles=joined, loc=3,fontsize=legend_size))

# %%
figure = LimitFigure(e_power=1, xlims=(1e6, 1e11), ylims=(2e-19, 2e-14), font_size=16, tick_size=14)
# figure.build_base_plot('ara',models = ['ahlers_1','ahlers_100','batista','batista_low_z','van_vliet2019', 'van_vliet2019_Elow', 'wittkowski_off','wittkowski','van_vliet2019_hard','van_vliet2019_soft','diagonal','kotera_FRII','vanvliet19_highE_hard','kotera'])
figure.build_base_plot('ara',models = ['ahlers_1','diagonal','van_vliet2019',"murase_grb","fang_pulsar_max"], experiments=['ice_cube_mu_fit'])
# figure.add_limit('ARA', ara_energies, ara_available*0.9,
#                 stations=2.44, years=1, color='black', linestyle="dotted",
#                 label='Available Data (2012-2019)')
# figure.add_limit('ARA', ara_energies, ara_available*0.9,
#                 stations=2.44, years=1, color='black', linestyle="dotted",
#                 label='Available Data (2022)')
# figure.add_limit('ARA', ara_energies, ara_projected*0.9,
#                 stations=2.44, years=1, color='black', linestyle='dashed',
#                 label='Projected Data (2012-2022)')
figure.add_limit('ARA', ara_energies, ara_projected_2026*0.9,
                stations=2.44, years=1, color='black', linestyle='dashed',
                label='Projected Data (2026)', linewidth=1.5)
figure.add_limit('ARA', ara_energies, ara_projected_2030*0.9,
                stations=2.44, years=1, color='black', linestyle='dashed',
                label='Projected Data (2030)')
figure.ax.annotate('SES', xy=(1.7e8,1e-17), rotation=-48, fontsize=14)

figure.show(legend_size=12, save_name='e1_sensitivity_plot_ara2022.pdf')
# Out:
# /users/PAS0654/jflaherty13/araAnalysis/araGrant/yearlyNeutrinosPlotting/limits.py:751: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2b7c42214730> has a label of '_child1' which cannot be automatically added to the legend.
#   self.ax.add_artist(plt.legend(handles=joined, loc=3,fontsize=legend_size))

# %%
# figure = LimitFigure(e_power=1, xlims=(1e6, 1e11), ylims=(1e-19, 2e-14), font_size=16, tick_size=14)
# figure.build_base_plot('ara_src')
# figure.add_limit('ARA', ara_energies, ara_available*0.9,
#                 stations=2.44, years=1, color='black', linestyle=None,
#                 label='Available Data (2012-2020)')
# # figure.add_limit('ARA', ara_energies, ara_projected*0.9,
# #                 stations=2.44, years=1, color='black', linestyle='--',
# #                 label='Projected Data (2012-2023)')
# figure.add_limit('ARA', ara_energies, ara_projected*0.9,
#                 stations=2.44, years=1, color='black', linestyle='--',
#                 label='Projected Data (2012-2030)')

# figure.show(legend_size=12)#, save_name='e1_source_plot_ara2019.pdf')

# %% [markdown]
#   # Neutrinos per year

# %%
import neutrino_plots
importlib.reload(neutrino_plots)
from limits import (LimitFigure, count_neutrinos, ara_energies,
                    ara_100m, ara_200m, ara_200mpa)

fluxes = {
#         "SFR $E_{max}=10^{21.5}$, Kotera et al.": neutrino_plots.kotera_high_e_flux,
#         "SFR $E_{max}=10^{20.5}$, Kotera et al.": neutrino_plots.kotera_sfr_flux,
        "Astrophysical + cosmogenic - saturate limits": neutrino_plots.pulsar_koteraFRII,
        "Cosmogenic - saturate limits": neutrino_plots.kotera_FRII,
        "Astrophysical (pulsars)": neutrino_plots.fang_pulsar_max_flux,
        "IceCube $E^{-2.19}$ Extrapolated": lambda e: LimitFigure._i3_nu_fit(e, slope=-2.19, offset=1.01),

#         "100% protons, Ahlers & Halzen": neutrino_plots.ahlers_100_flux,
#         "10% protons, Ahlers & Halzen": neutrino_plots.ahlers_10_flux,
#         "1% protons, Ahlers & Halzen": neutrino_plots.ahlers_1_flux,
    }

styles = {
#     "SFR $E_{max}=10^{21.5}$, Kotera et al.": "deeppink.--",
#     "SFR $E_{max}=10^{20.5}$, Kotera et al.": "darkmagenta.--",
    "Astrophysical + cosmogenic - saturate limits": "darkmagenta.-",
    "Cosmogenic - saturate limits": "deeppink.-",
    "Astrophysical (pulsars)": "royalblue.-",
    "IceCube $E^{-2.19}$ Extrapolated": "dodgerblue.-",

    
#     "100% protons, Ahlers & Halzen": "mediumblue.-.",
#     "10% protons, Ahlers & Halzen": "royalblue.-.",
#     "1% protons, Ahlers & Halzen": "cornflowerblue.-.",
}

# ara_by_year = [284*ara_100m/366, (217+233)*ara_200m/365, (124*ara_100m+(313+304)*ara_200m)/365,
#                (345+250)*ara_200m/365, (127*ara_100m+(323+297)*ara_200m)/366, 137*ara_200m/365,
#                (316*ara_100m+(303+316+313)*ara_200m+186*ara_200mpa)/365,
#                ara_100m+3*ara_200m+ara_200mpa, ara_100m+3*ara_200m+ara_200mpa, ara_100m+3*ara_200m+ara_200mpa,ara_100m+3*ara_200m+ara_200mpa]
              
ara_by_year = [284*ara_100m/366, #2012
               (217+233)*ara_200m/365, #2013
               (124*ara_100m+(313+304)*ara_200m)/365, #2014
               (345+250)*ara_200m/365, #2015
               (127*ara_100m+(323+297)*ara_200m)/366, #2016
               137*ara_200m/365,#2017
               (316*ara_100m+(303+316+313)*ara_200m+186*ara_200mpa)/365,#2018
               ara_100m+3*ara_200m+ara_200mpa, #2019
               ara_100m+3*ara_200m+ara_200mpa, #2020  A5/PA merged, need to see if V_eff changed
               ara_100m+1*ara_200m+(121/365)*ara_200m+(15/365)*ara_200m+ara_200mpa, #2021  ARA2 died May 1st, ARA4 died Jan 15th.
               ara_100m+1*ara_200m+ara_200mpa, #2022
               ara_100m+2*ara_200m+ara_200mpa, #2023 Plan to repair A2
               ara_100m+3*ara_200m+ara_200mpa, #2024 Plan to repair A4
               ara_100m+3*ara_200m+ara_200mpa, #2025
               ara_100m+3*ara_200m+ara_200mpa, #2026
               ara_100m+3*ara_200m+ara_200mpa, #2027
               ara_100m+3*ara_200m+ara_200mpa, #2028
               ara_100m+3*ara_200m+ara_200mpa, #2029
               ara_100m+3*ara_200m+ara_200mpa] #2030

# neutrino_plots.plot_neutrinos_by_year_ara(fluxes, ara_energies, ara_by_year, styles=styles,
#                            years=[2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
#                            stations=["ARA 1", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-5"],
#                            save_name='yearly_neutrinos_ara_fluxes_2019proposal.pdf',xlim=[2012,2023])

neutrino_plots.plot_neutrinos_by_year_ara(fluxes, ara_energies, ara_by_year, styles=styles,
                           years=[2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030],
                           stations=["ARA 1", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-5"],
                           save_name='yearly_neutrinos_ara_fluxes_2019proposal.pdf',xlim=[2012,2030])


# fluxes = {
#     "AGN, Murase": neutrino_plots.murase_agn_flux,
#     "GRB afterglow-late prompt, Murase": neutrino_plots.murase_grb_late_flux,
#     "GRB afterglow-wind, Murase": neutrino_plots.murase_grb_wind_flux,
#     "GRB afterglow-ISM, Murase": neutrino_plots.murase_grb_ism_flux,
#     "Clusters, Fang & Murase": neutrino_plots.fang_cluster_flux,
# }

# styles = {
#     "AGN, Murase": "red.--",
#     "GRB afterglow-late prompt, Murase": "saddlebrown.-.",
#     "GRB afterglow-wind, Murase": "goldenrod.-.",
#     "GRB afterglow-ISM, Murase": "gold.-.",
#     "Clusters, Fang & Murase": "mediumvioletred.&",
# }

# neutrino_plots.plot_neutrinos_by_year_ara(fluxes, ara_energies, ara_by_year, styles=styles,
#                            years=[2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
#                            stations=["ARA 1", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-5"])#,
# #                            save_name='yearly_neutrinos_ara_sources_2019proposal.pdf')

# %%
##For Iyla.  Goes to 2026
import neutrino_plots
importlib.reload(neutrino_plots)
from limits import (LimitFigure, count_neutrinos, ara_energies,
                    ara_100m, ara_200m, ara_200mpa)

fluxes = {
#         "SFR $E_{max}=10^{21.5}$, Kotera et al.": neutrino_plots.kotera_high_e_flux,
#         "SFR $E_{max}=10^{20.5}$, Kotera et al.": neutrino_plots.kotera_sfr_flux,
        "Astrophysical + cosmogenic - saturate limits": neutrino_plots.pulsar_koteraFRII,
        "Cosmogenic - saturate limits": neutrino_plots.kotera_FRII,
        "Astrophysical (pulsars)": neutrino_plots.fang_pulsar_max_flux,
        "IceCube $E^{-2.19}$ Extrapolated": lambda e: LimitFigure._i3_nu_fit(e, slope=-2.19, offset=1.01),

#         "100% protons, Ahlers & Halzen": neutrino_plots.ahlers_100_flux,
#         "10% protons, Ahlers & Halzen": neutrino_plots.ahlers_10_flux,
#         "1% protons, Ahlers & Halzen": neutrino_plots.ahlers_1_flux,
    }

styles = {
#     "SFR $E_{max}=10^{21.5}$, Kotera et al.": "deeppink.--",
#     "SFR $E_{max}=10^{20.5}$, Kotera et al.": "darkmagenta.--",
    "Astrophysical + cosmogenic - saturate limits": "darkmagenta.-",
    "Cosmogenic - saturate limits": "deeppink.-",
    "Astrophysical (pulsars)": "royalblue.-",
    "IceCube $E^{-2.19}$ Extrapolated": "dodgerblue.-",

    
#     "100% protons, Ahlers & Halzen": "mediumblue.-.",
#     "10% protons, Ahlers & Halzen": "royalblue.-.",
#     "1% protons, Ahlers & Halzen": "cornflowerblue.-.",
}

# ara_by_year = [284*ara_100m/366, (217+233)*ara_200m/365, (124*ara_100m+(313+304)*ara_200m)/365,
#                (345+250)*ara_200m/365, (127*ara_100m+(323+297)*ara_200m)/366, 137*ara_200m/365,
#                (316*ara_100m+(303+316+313)*ara_200m+186*ara_200mpa)/365,
#                ara_100m+3*ara_200m+ara_200mpa, ara_100m+3*ara_200m+ara_200mpa, ara_100m+3*ara_200m+ara_200mpa,ara_100m+3*ara_200m+ara_200mpa]
              
ara_by_year = [284*ara_100m/366, #2012
               (217+233)*ara_200m/365, #2013
               (124*ara_100m+(313+304)*ara_200m)/365, #2014
               (345+250)*ara_200m/365, #2015
               (127*ara_100m+(323+297)*ara_200m)/366, #2016
               137*ara_200m/365,#2017
               (316*ara_100m+(303+316+313)*ara_200m+186*ara_200mpa)/365,#2018
               ara_100m+3*ara_200m+ara_200mpa, #2019
               ara_100m+3*ara_200m+ara_200mpa, #2020  A5/PA merged, need to see if V_eff changed
               ara_100m+1*ara_200m+(121/365)*ara_200m+(15/365)*ara_200m+ara_200mpa, #2021  ARA2 died May 1st, ARA4 died Jan 15th.
               ara_100m+1*ara_200m+ara_200mpa, #2022
               ara_100m+2*ara_200m+ara_200mpa, #2023 Plan to repair A2
               ara_100m+3*ara_200m+ara_200mpa, #2024 Plan to repair A4
               ara_100m+3*ara_200m+ara_200mpa, #2025
               ara_100m+3*ara_200m+ara_200mpa] #2026
               # ara_100m+3*ara_200m+ara_200mpa, #2027
               # ara_100m+3*ara_200m+ara_200mpa, #2028
               # ara_100m+3*ara_200m+ara_200mpa, #2029
               # ara_100m+3*ara_200m+ara_200mpa] #2030

# neutrino_plots.plot_neutrinos_by_year_ara(fluxes, ara_energies, ara_by_year, styles=styles,
#                            years=[2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
#                            stations=["ARA 1", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-5"],
#                            save_name='yearly_neutrinos_ara_fluxes_2019proposal.pdf',xlim=[2012,2023])

neutrino_plots.plot_neutrinos_by_year_ara(fluxes, ara_energies, ara_by_year, styles=styles,
                           years=[2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026],
                           stations=["ARA 1", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-5"],
                           save_name='yearly_neutrinos_ara_fluxes_2019proposal.pdf',xlim=[2012,2026])


# fluxes = {
#     "AGN, Murase": neutrino_plots.murase_agn_flux,
#     "GRB afterglow-late prompt, Murase": neutrino_plots.murase_grb_late_flux,
#     "GRB afterglow-wind, Murase": neutrino_plots.murase_grb_wind_flux,
#     "GRB afterglow-ISM, Murase": neutrino_plots.murase_grb_ism_flux,
#     "Clusters, Fang & Murase": neutrino_plots.fang_cluster_flux,
# }

# styles = {
#     "AGN, Murase": "red.--",
#     "GRB afterglow-late prompt, Murase": "saddlebrown.-.",
#     "GRB afterglow-wind, Murase": "goldenrod.-.",
#     "GRB afterglow-ISM, Murase": "gold.-.",
#     "Clusters, Fang & Murase": "mediumvioletred.&",
# }

# neutrino_plots.plot_neutrinos_by_year_ara(fluxes, ara_energies, ara_by_year, styles=styles,
#                            years=[2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
#                            stations=["ARA 1", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-3", "ARA 1-5"])#,
# #                            save_name='yearly_neutrinos_ara_sources_2019proposal.pdf')

# %%
# station_years= [284/366, (217+233)/365, (124+(313+304))/365, #2012 - 2014
#                (345+250)/365, (127+(323+297))/366, 137/365, #2015 - 2017
#                (316+(303+316+313)+186)/365, #2018
#                1+3+1, 1+3+1, 1+3*1+1,1+3*1+1] #2019 - 2022

station_years= [284/366, #2012
                (217+233)/365, #2013
                (124+(313+304))/365, #2014
               (345+250)/365, #2015
                (127+(323+297))/366, #2016
                137/365, #2017
               (316+(303+316+313)+186)/365, #2018
               1+3+1, #2019
                1+3+1, #2020
                1+1*1+(121/365)*1+(15/365)*1+1, #2021  ARA2 died May 1st, ARA4 died Jan 15th.
                1+1*1+1, #2022
                1+2*1+1, #2023
                1+3*1+1, #2024
                1+3*1+1, #2025
                1+3*1+1, #2026
                1+3*1+1, #2027
                1+3*1+1, #2028
                1+3*1+1, #2029
                1+3*1+1] #2030

startYear=2012
endYear=2030
numYears=endYear-startYear
station_years_per_station = np.zeros((numYears+1,5))

#Define station live times per year
station_years_per_station[0,:] =  [284/366, 0, 0, 0, 0] #2012
station_years_per_station[1,:] =  [0, 217/365, 233/365, 0, 0] #2013
station_years_per_station[2,:] =  [124/365, 313/365, 304/365, 0, 0] #2014
station_years_per_station[3,:] =  [29/365, 345/365, 250/365, 0, 0] #2015
station_years_per_station[4,:] =  [127/366, 323/366, 297/366, 0, 0] #2016
station_years_per_station[5,:] =  [0, 137/365, 0, 0, 0] #2017
station_years_per_station[6,:] =  [349/365, 327/365, 332/365, 344/365, 212/365] #2018
station_years_per_station[7,:] =  [325/365, 211/365, 326/365, 326/365, 260/365] #2019
station_years_per_station[8,:] =  [360/366, 346/366, 361/366, 361/366, 257/366] #2020
station_years_per_station[9,:] =  [1, 121/365, 1, 15/365, 260/365] #2021
station_years_per_station[10,:] =  [1, 0, 1, 0, 260/365] #2022
station_years_per_station[11,:] =  [1, 1, 1, 0, 260/365] #2023
station_years_per_station[12,:] =  [1, 1, 1, 1, 260/365] #2024
station_years_per_station[13,:] =  [1, 1, 1, 1, 260/365] #2025
station_years_per_station[14,:] =  [1, 1, 1, 1, 260/365] #2026
station_years_per_station[15,:] =  [1, 1, 1, 1, 260/365] #2027
station_years_per_station[16,:] =  [1, 1, 1, 1, 260/365] #2028
station_years_per_station[17,:] =  [1, 1, 1, 1, 260/365] #2029
station_years_per_station[18,:] =  [1, 1, 1, 1, 260/365] #2030

# %%
cumulative=0
year=2012
for i in range(0,len(station_years)):
    cumulative+=station_years[i]
    print(str(year) + "\t"+"%0.2f"%cumulative)
    year+=1
# Out:
# 2012	0.78
# 2013	2.01
# 2014	4.04
# 2015	5.67
# 2016	7.71
# 2017	8.09
# 2018	12.01
# 2019	17.01
# 2020	22.01
# 2021	25.39
# 2022	28.39
# 2023	32.39
# 2024	37.39
# 2025	42.39
# 2026	47.39
# 2027	52.39
# 2028	57.39
# 2029	62.39
# 2030	67.39

# %%
cumulative=np.zeros(5)
year=2012
print("Year \tA1 \tA2 \tA3 \tA5 \tA5/PA \tTotal Station Years")
for i in range(0,len(station_years_per_station)):
    cumulative+=station_years_per_station[i,:]
    print(str(year) + "\t"+"%0.2f"%cumulative[0]+ "\t"+"%0.2f"%cumulative[1]+ "\t"+"%0.2f"%cumulative[2]+ "\t"+"%0.2f"%cumulative[3]+ "\t"+"%0.2f"%cumulative[4]+ "\t"+"%0.2f"%cumulative.sum())
    year+=1
# Out:
# Year 	A1 	A2 	A3 	A5 	A5/PA 	Total Station Years
# 2012	0.78	0.00	0.00	0.00	0.00	0.78
# 2013	0.78	0.59	0.64	0.00	0.00	2.01
# 2014	1.12	1.45	1.47	0.00	0.00	4.04
# 2015	1.20	2.40	2.16	0.00	0.00	5.75
# 2016	1.54	3.28	2.97	0.00	0.00	7.79
# 2017	1.54	3.66	2.97	0.00	0.00	8.16
# 2018	2.50	4.55	3.88	0.94	0.58	12.45
# 2019	3.39	5.13	4.77	1.84	1.29	16.42
# 2020	4.37	6.07	5.76	2.82	2.00	21.02
# 2021	5.37	6.41	6.76	2.86	2.71	24.11
# 2022	6.37	6.41	7.76	2.86	3.42	26.82
# 2023	7.37	7.41	8.76	2.86	4.13	30.53
# 2024	8.37	8.41	9.76	3.86	4.84	35.24
# 2025	9.37	9.41	10.76	4.86	5.56	39.96
# 2026	10.37	10.41	11.76	5.86	6.27	44.67
# 2027	11.37	11.41	12.76	6.86	6.98	49.38
# 2028	12.37	12.41	13.76	7.86	7.69	54.09
# 2029	13.37	13.41	14.76	8.86	8.41	58.80
# 2030	14.37	14.41	15.76	9.86	9.12	63.52

# %%
#Do the table above, but as a latex output
cumulative=np.zeros(5)
year=2012
print("\\begin{center}")
print("\\begin{tabular}{||c c c c c c c||} ")
print("\\hline")
print("Year & A1 & A2 & A3 & A5 & A5/PA & Total Station Years \\\\")
print("\\hline")
for i in range(0,len(station_years_per_station)):
    cumulative+=station_years_per_station[i,:]
    print(str(year) + " & "+"%0.2f"%cumulative[0]+ " & "+"%0.2f"%cumulative[1]+ " & "+"%0.2f"%cumulative[2]+ " & "+"%0.2f"%cumulative[3]+ " & "+"%0.2f"%cumulative[4]+ " & "+"%0.2f"%cumulative.sum() + "\\\\")
    print("\\hline")
    year+=1
print("\\end{tabular} ")
print("\\end{center}")
# Out:
# \begin{center}
# \begin{tabular}{||c c c c c c c||}
# \hline
# Year & A1 & A2 & A3 & A5 & A5/PA & Total Station Years \\
# \hline
# 2012 & 0.78 & 0.00 & 0.00 & 0.00 & 0.00 & 0.78\\
# \hline
# 2013 & 0.78 & 0.59 & 0.64 & 0.00 & 0.00 & 2.01\\
# \hline
# 2014 & 1.12 & 1.45 & 1.47 & 0.00 & 0.00 & 4.04\\
# \hline
# 2015 & 1.20 & 2.40 & 2.16 & 0.00 & 0.00 & 5.75\\
# \hline
# 2016 & 1.54 & 3.28 & 2.97 & 0.00 & 0.00 & 7.79\\
# \hline
# 2017 & 1.54 & 3.66 & 2.97 & 0.00 & 0.00 & 8.16\\
# \hline
# 2018 & 2.50 & 4.55 & 3.88 & 0.94 & 0.58 & 12.45\\
# \hline
# 2019 & 3.39 & 5.13 & 4.77 & 1.84 & 1.29 & 16.42\\
# \hline
# 2020 & 4.37 & 6.07 & 5.76 & 2.82 & 2.00 & 21.02\\
# \hline
# 2021 & 5.37 & 6.41 & 6.76 & 2.86 & 2.71 & 24.11\\
# \hline
# 2022 & 6.37 & 6.41 & 7.76 & 2.86 & 3.42 & 26.82\\
# \hline
# 2023 & 7.37 & 7.41 & 8.76 & 2.86 & 4.13 & 30.53\\
# \hline
# 2024 & 8.37 & 8.41 & 9.76 & 3.86 & 4.84 & 35.24\\
# \hline
# 2025 & 9.37 & 9.41 & 10.76 & 4.86 & 5.56 & 39.96\\
# \hline
# 2026 & 10.37 & 10.41 & 11.76 & 5.86 & 6.27 & 44.67\\
# \hline
# 2027 & 11.37 & 11.41 & 12.76 & 6.86 & 6.98 & 49.38\\
# \hline
# 2028 & 12.37 & 12.41 & 13.76 & 7.86 & 7.69 & 54.09\\
# \hline
# 2029 & 13.37 & 13.41 & 14.76 & 8.86 & 8.41 & 58.80\\
# \hline
# 2030 & 14.37 & 14.41 & 15.76 & 9.86 & 9.12 & 63.52\\
# \hline
# \end{tabular}
# \end{center}

# %%
ara_by_year
# Out:
# [array([ 0.07549211,  0.38325816,  1.3746732 ,  3.32090999,  6.36363583,
#         12.03244012, 22.42344502, 37.08363195]),
#  array([ 0.10743415,  0.57830442,  2.1373958 ,  6.39118935, 13.63561644,
#         25.45847424, 42.15179516, 62.90709576]),
#  array([  0.18035581,   0.96071615,   3.53246096,  10.21697806,
#          21.48204639,  40.17439095,  67.61213629, 102.48842302]),
#  array([ 0.14205182,  0.76464696,  2.82611222,  8.45057259, 18.02931507,
#         33.66176039, 55.73404027, 83.17715995]),
#  array([  0.18137476,   0.96598457,   3.551541  ,  10.26663436,
#          21.58122951,  40.36098753,  67.94451523, 103.01836331]),
#  array([ 0.03270773,  0.17606157,  0.65071828,  1.94576209,  4.15128767,
#          7.75069105, 12.83287986, 19.15171582]),
#  array([  0.47457335,   2.30367428,   8.11243638,  22.04611026,
#          45.79727105,  85.65226599, 150.32297127, 226.63567322]),
#  array([  0.68806957,   3.23225814,  11.19538829,  29.84762414,
#          61.90016592, 115.72177467, 206.04401438, 308.74187974]),
#  array([  0.68806957,   3.23225814,  11.19538829,  29.84762414,
#          61.90016592, 115.72177467, 206.04401438, 308.74187974]),
#  array([  0.54625649,   2.4688963 ,   8.37402584,  21.41125419,
#          43.90115222,  82.11658868, 150.40364476, 225.70451333]),
#  array([  0.5137875 ,   2.29411986,   7.72805733,  19.47969475,
#          39.78016592,  74.42247202, 137.66443556, 206.69259106]),
#  array([  0.60092853,   2.763189  ,   9.46172281,  24.66365944,
#          50.84016592,  95.07212335, 171.85422497, 257.7172354 ]),
#  array([  0.68806957,   3.23225814,  11.19538829,  29.84762414,
#          61.90016592, 115.72177467, 206.04401438, 308.74187974]),
#  array([  0.68806957,   3.23225814,  11.19538829,  29.84762414,
#          61.90016592, 115.72177467, 206.04401438, 308.74187974]),
#  array([  0.68806957,   3.23225814,  11.19538829,  29.84762414,
#          61.90016592, 115.72177467, 206.04401438, 308.74187974])]

# %%
##Plotting effective volumes
import numpy as np
import matplotlib.pyplot as plt
v100 = np.array([8.818E-2/1.853935, 4.006E-1/1.426338, 1.381E+0/1.231167, 3.143E+0/1.088942,
                          6.155E+0/1.103670, 1.045E+1, 1.565E+1, 2.248E+1])
v200 = np.array([1.105E-1, 5.195E-1, 1.826E+0, 5.259E+0,
                          1.106E+1, 2.077E+1, 3.431E+1, 5.073E+1])

energy = 10**np.array([16.5, 17.0, 17.5, 18.0, 18.5, 19.0, 19.5, 20.0])

# %%
plt.figure(figsize=(8,8))
plt.plot(np.log10(energy), v100, label = "V_eff for 100m")
plt.plot(np.log10(energy), v200, label = "V_eff for 200m")
plt.xlabel("Log( Energy [eV] )")
plt.ylabel("Effective Volume [units unknown at the moment]")
plt.legend()
plt.grid()

# %%
plt.figure(figsize=(8,8))
plt.plot(np.log10(energy), v100, label = "V_eff for 100m")
plt.plot(np.log10(energy), v200, label = "V_eff for 200m")
plt.xlabel("Log( Energy [eV] )")
plt.ylabel("Effective Volume [units unknown at the moment]")
plt.yscale("log")
plt.legend()
plt.grid()

# %%
plt.figure(figsize=(8,8))
# plt.plot(np.log10(energy), v100, label = "V_eff for 100m")
plt.plot(np.log10(energy), v200/v100, label = "Ratio of V_eff for 200m to 100m")
plt.xlabel("Log( Energy [eV] )")
plt.ylabel("Ratio of v200/v100 [-]")
plt.legend()
plt.grid()
